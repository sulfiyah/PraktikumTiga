# %% [markdown]
# **Weekly Exercise 1**

# %%
with open('sample_data/biodata_falikha_sulfiyah.txt', 'r') as writefile:
  print(writefile.read())
# Out:
# Nama : Falikha Sulfiyah
# Program Studi : Teknologi Informasi
# NPM : 2420506042
# Alamat : Cirebon, Jawa Barat
# Hobi : Fangirl
# Email : falikhasulfiyah@gmail.com

# %%
with open('sample_data/biodata_falikha_sulfiyah.txt', "r") as testwritefile:
  for line in testwritefile:
    if "Nama" in line or "Program Studi" in line or "Email" in line:
      print(line.strip())
# Out:
# Nama : Falikha Sulfiyah
# Program Studi : Teknologi Informasi
# Email : falikhasulfiyah@gmail.com

# %%
with open('sample_data/biodata_falikha_sulfiyah.txt', "r") as readfile:
  with open('sample_data/biodata_falikha_sulfiyah_copy.txt', "w") as writefile:
    for line in readfile:
      writefile.write(line)

# %%
with open('sample_data/biodata_falikha_sulfiyah.txt', 'r') as testwritefile:
  for line in testwritefile:
    if "Nama" in line or "NPM" in line or "Program Studi" in line or "Alamat" in line:
      print(line.strip())
# Out:
# Nama : Falikha Sulfiyah
# Program Studi : Teknologi Informasi
# NPM : 2420506042
# Alamat : Cirebon, Jawa Barat

# %% [markdown]
# **Weekly Exercise 2**

# %%
print("Selamat Datang di Toko Maju Jaya")
print("Senin, 4 September 2024   13.05")
print(" ")
print("DAFTAR BELANJA :")
item1 = "Sabun"
item2 = "Shampo"
item3 = "Mie Instan"
item4 = "Detergen"
harga1 = 10000
harga2 = 15000
harga3 = 5000
harga4 = 17500

total = harga1 + harga2 + harga3 + harga4

print(item1, "= Rp" , + harga1)
print(item2, "= Rp" , + harga2)
print(item3, "= Rp" , + harga3)
print(item4, "= Rp" , + harga4)
print("")
print("Total = Rp", + total)

with open('Kuitansi.txt', 'w') as writefile:
  writefile.write("Selamat Datang di Toko Maju Jaya")
  writefile.write("\n")
  writefile.write("Kuitansi - 4 September 2024")
  writefile.write("\n")
  writefile.write("DAFTAR BELANJA :")
  writefile.write("\n")
  writefile.write(item1+ "= Rp" +str(harga1)+"\n")
  writefile.write(item2+ "= Rp" +str(harga2)+"\n")
  writefile.write(item3+ "= Rp" +str(harga3)+"\n")
  writefile.write(item4+ "= Rp" +str(harga4)+"\n")
  writefile.write("Total = Rp" +str(total))
# Out:
# Selamat Datang di Toko Maju Jaya
# Senin, 4 September 2024   13.05
#
# DAFTAR BELANJA :
# Sabun = Rp 10000
# Shampo = Rp 15000
# Mie Instan = Rp 5000
# Detergen = Rp 17500
#
# Total = Rp 47500
